# %%
# Create a NumPy array of student marks: [78, 85, 62, 90, 55, 88]
import numpy as np
marks = np.array([78, 85, 62, 90, 55, 88])
tot_marks = marks.sum()
print(tot_marks)
print(marks.mean())
print(marks.max())
print(marks.min())
print(marks.std())
print(np.median(marks))
#apply 5 marks to all 
scalar = 5
new_marks = marks + 5
print(new_marks)
#now multiply all marks by 1.1
new_marks1 = new_marks * 1.1
print(new_marks1)
# Out:
# 458
# 76.33333333333333
# 90
# 55
# 13.299958228840003
# 81.5
# [83 90 67 95 60 93]
# [ 91.3  99.   73.7 104.5  66.  102.3]
