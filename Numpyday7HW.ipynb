# %%
#Create a NumPy array of daily temperatures: [28, 30, 32, 35, 33]
import numpy as np 
import sys
faren_list = []
f = 0 
temp = np.array([28, 30, 32, 35, 33])
for t in temp:
    f = ((t*9/5)+32)
    faren_list.append(f)   #here am appending each temperatures

print(faren_list)
temp_faren = ((temp*9/5)+32)
print(temp_faren)
print(sys.getsizeof(faren_list))  
print(temp_faren.nbytes)
# Out:
# [82.4, 86.0, 89.6, 95.0, 91.4]
# [82.4 86.  89.6 95.  91.4]
# 120
# 40
